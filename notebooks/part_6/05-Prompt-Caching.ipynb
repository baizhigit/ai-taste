# %% [markdown]
# ### Import Dependecies

# %%
import instructor
from openai import OpenAI
from pydantic import BaseModel
from typing import Optional, List

# %%
client = instructor.from_openai(OpenAI())

# %%
text = """
The City Beneath the Observatory

When the last train stopped running beneath the northern cliffs, most people assumed the tunnels would slowly fill with water and memory. Rust would climb the rails, dust would settle over the station clocks, and the city would move on. But the tunnels remained dry. Their lights, somehow, still flickered at irregular intervals even after the electric grid was disconnected. The ventilation fans continued to hum beneath the stone. And every winter, during the coldest week of the year, people standing near the abandoned entrances claimed they could hear distant announcements echoing from underground.

No one agreed on what the announcements said.

Some heard warnings.
Others heard numbers.
A few heard their own names.

Mira first descended into the tunnels because she wanted silence.

The upper city had become unbearable during the years after the observatory closed. Every district was crowded with repair drones, delivery engines, market screens, political broadcasts, emergency sirens, and the endless noise of construction. Buildings were never finished anymore. They only evolved into newer shapes. One month a tower would hold apartments, then laboratories, then vertical farms, then data centers wrapped in mirrored glass. Streets changed direction every season. Maps became obsolete almost immediately.

But the abandoned rail network beneath the cliffs remained unchanged.

Mira discovered the eastern maintenance entrance while searching for old copper wiring in the industrial quarter. The door was hidden behind collapsed scaffolding and marked with symbols faded almost white by salt wind. She expected darkness beyond it, but instead found a corridor softly lit by amber ceiling lamps.

The air underground smelled ancient.
Not rotten.
Not damp.
Simply old.

She walked for nearly an hour before reaching the first station.

The sign above the platform read:

NORTH ARCHIVE TERMINAL

The station looked untouched. Benches stood in perfect rows. Maps hung behind cracked protective glass. Ticket machines displayed static blue screens. A maintenance cart sat beside the tracks with tools arranged neatly across its shelves as if workers had vanished moments earlier.

Mira approached the platform edge and looked down the tunnel.

Far away, something moved.

At first she thought it was another explorer carrying a lantern. Then she realized the light was approaching too steadily. It glided through the darkness without wobbling.

A train emerged.

It was silent.

Not quieter than ordinary trains.
Truly silent.

Its wheels produced no friction. Its metal frame created no vibration. Even the wind displaced by its arrival made no sound. The train slowed beside the platform and opened its doors.

Inside, warm lights illuminated empty seats.

Mira stared for several seconds.
Then stepped aboard.

The doors closed immediately.

The train accelerated into darkness.

No controls were visible inside the carriage. No advertisements covered the walls. No route display marked upcoming stations. The windows revealed only black tunnels occasionally interrupted by flashes of old maintenance lights.

After several minutes, a voice spoke overhead.

"Passenger detected," it said.

The voice sounded calm but imperfect, as though assembled from fragments of many different speakers.

"Destination unavailable. Route adjustment in progress."

Mira stood.
"Who operates this line?"

No answer came.

The train continued forward.

She moved between carriages searching for staff but found only more empty compartments. Some were pristine. Others contained scattered papers, abandoned luggage, and faded blankets folded across seats.

One carriage held plants growing from cracks in the floor.
Small white flowers climbed the walls beneath flickering lights.

The farther she walked, the stranger the train became.

In one compartment the ceiling projected a moving night sky. Stars drifted slowly overhead in patterns she did not recognize. In another carriage, transparent cylinders filled with dark liquid lined the walls from floor to ceiling.

Each cylinder contained mechanical parts suspended inside.
Hands.
Eyes.
Lengths of silver cable resembling nerves.

Mira backed away quickly.

The train finally slowed after what felt like an hour.

Outside the windows appeared not a station but an enormous underground cavern.

Buildings filled the space beneath the earth.

Mira pressed her face to the glass.

The cavern was impossible.

Thousands of structures rose beneath the stone ceiling: towers connected by bridges, glowing gardens suspended from steel arches, rotating machinery larger than entire city blocks. Rivers of pale blue water flowed through artificial channels. Lights drifted through the air like slow insects.

There was no twenty-first floor.

Yet the elevator doors opened onto a hallway.

Warm yellow lights illuminated unfamiliar walls.
Paintings hung beside apartment doors she had never seen before.
At the hallway end stood a window overlooking the city.

Mira stepped out slowly.

From somewhere inside one apartment came the sound of a child laughing.
Another door opened briefly farther down the corridor.
An elderly woman exited carrying groceries.
She nodded politely at Mira before disappearing into the elevator.

As though this floor had always existed.

Mira approached the window.

Outside, the skyline shimmered.

For an instant she saw two versions of the city overlapping each other.
One familiar.
One impossible.

Then the sphere in her pocket flashed brightly.

The hallway vanished.

Mira stood once again inside the ordinary elevator between floors eighteen and nineteen.
The doors remained closed.

She leaned against the wall breathing hard.

Somewhere far below the city, hidden beneath stone and steel, the containment engine continued turning.

And above it, reality was beginning to come apart.
"""

# %%
def print_usage_and_cost(raw_response):
    # gpt-5.4-mini pricing
    input_price = 0.75/1000000
    output_price = 4.5/1000000
    cached_price = 0.075/1000000

    input_tokens = raw_response.usage.prompt_tokens
    output_tokens = raw_response.usage.completion_tokens
    cached_tokens = raw_response.usage.prompt_tokens_details.cached_tokens
    non_cached_tokens = input_tokens - cached_tokens

    print(f"Input tokens: {input_tokens}")
    print(f"Output tokens: {output_tokens}")
    print(f"Cached tokens: {cached_tokens}")
    print(f"Non-cached tokens: {non_cached_tokens}")

    print(f"Output cost: {output_tokens * output_price}")
    print(f"Cached cost: {cached_tokens * cached_price}")
    print(f"Non-cached cost: {non_cached_tokens * input_price}")

# %%
prompt_1 = f"""
Extract names from the following text:

{text}
"""

# %%
prompt_2 = f"""
Extract places from the following text:

{text}
"""

# %%
class ExtractedNames(BaseModel):
    names: List[str]

class ExtractedPlaces(BaseModel):
    places: List[str]

# %%
response_1, raw_response_1 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractedNames,
    messages=[
        {"role": "system", "content": prompt_1},
    ]
)

# %%
response_2, raw_response_2 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractedPlaces,
    messages=[
        {"role": "system", "content": prompt_2},
    ]
)

# %%
raw_response_1.usage
# Out:
# CompletionUsage(completion_tokens=31, prompt_tokens=4763, total_tokens=4794, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
print_usage_and_cost(raw_response_1)
# Out:
# Input tokens: 4763
# Output tokens: 40
# Cached tokens: 4608
# Non-cached tokens: 155
# Output cost: 0.00018
# Cached cost: 0.0003456
# Non-cached cost: 0.00011625

# %%
print_usage_and_cost(raw_response_2)
# Out:
# Input tokens: 4763
# Output tokens: 118
# Cached tokens: 4608
# Non-cached tokens: 155
# Output cost: 0.000531
# Cached cost: 0.0003456
# Non-cached cost: 0.00011625

# %%
prompt_3 = f"""
<text>
{text}
</text>

Extract names from the text between <text> and </text> tags:
"""

# %%
prompt_4 = f"""
<text>
{text}
</text>

Extract places from the text between <text> and </text> tags:
"""

# %%
response_3, raw_response_3 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractedNames,
    messages=[
        {"role": "system", "content": prompt_3},
    ]
)

# %%
response_4, raw_response_4 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractedPlaces,
    messages=[
        {"role": "system", "content": prompt_4},
    ]
)

# %%
print_usage_and_cost(raw_response_3)
# Out:
# Input tokens: 4777
# Output tokens: 33
# Cached tokens: 0
# Non-cached tokens: 4777
# Output cost: 0.0001485
# Cached cost: 0.0
# Non-cached cost: 0.00358275

# %%
print_usage_and_cost(raw_response_4)
# Out:
# Input tokens: 4777
# Output tokens: 83
# Cached tokens: 3584
# Non-cached tokens: 1193
# Output cost: 0.0003735
# Cached cost: 0.0002688
# Non-cached cost: 0.00089475

# %%
print_usage_and_cost(raw_response_3)
# Out:
# Input tokens: 4777
# Output tokens: 24
# Cached tokens: 4608
# Non-cached tokens: 169
# Output cost: 0.000108
# Cached cost: 0.0003456
# Non-cached cost: 0.00012675

# %%
print_usage_and_cost(raw_response_4)
# Out:
# Input tokens: 4777
# Output tokens: 112
# Cached tokens: 4608
# Non-cached tokens: 169
# Output cost: 0.000504
# Cached cost: 0.0003456
# Non-cached cost: 0.00012675

# %%
prompt_3_1 = f"""
Following is the text with more than 4000 tokens.
<text>
{text}
</text>

Extract names from the text between <text> and </text> tags:
"""

prompt_4_1 = f"""
Following is the text with more than 4000 tokens.
<text>
{text}
</text>

Extract places from the text between <text> and </text> tags:
"""

# %%
response_3_1, raw_response_3_1 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractedNames,
    messages=[
        {"role": "system", "content": prompt_3_1},
    ]
)

# %%
response_4_1, raw_response_4_1 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractedPlaces,
    messages=[
        {"role": "system", "content": prompt_4_1},
    ]
)

# %%
print_usage_and_cost(raw_response_3_1)
# Out:
# Input tokens: 4789
# Output tokens: 24
# Cached tokens: 4608
# Non-cached tokens: 181
# Output cost: 0.000108
# Cached cost: 0.0003456
# Non-cached cost: 0.00013575

# %%
print_usage_and_cost(raw_response_4_1)
# Out:
# Input tokens: 4789
# Output tokens: 98
# Cached tokens: 3584
# Non-cached tokens: 1205
# Output cost: 0.000441
# Cached cost: 0.0002688
# Non-cached cost: 0.00090375

# %%
class ExtractionResults(BaseModel):
    names: Optional[List[str]] = None
    places: Optional[List[str]] = None

# %%
prompt_5 = f"""
Following is the text with more than 4000 tokens.
<text>
{text}
</text>

Extract names from the text between <text> and </text> tags, leave places as null.
"""

prompt_6 = f"""
Following is the text with more than 4000 tokens.
<text>
{text}
</text>

Extract places from the text between <text> and </text> tags, leave names as null.
"""

# %%
response_5, raw_response_5 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractionResults,
    messages=[
        {"role": "system", "content": prompt_5},
    ]
)

# %%
response_6, raw_response_6 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractionResults,
    messages=[
        {"role": "system", "content": prompt_6},
    ]
)

# %%
print_usage_and_cost(raw_response_5)
# Out:
# Input tokens: 4815
# Output tokens: 28
# Cached tokens: 4608
# Non-cached tokens: 207
# Output cost: 0.000126
# Cached cost: 0.0003456
# Non-cached cost: 0.00015525

# %%
print_usage_and_cost(raw_response_6)
# Out:
# Input tokens: 4815
# Output tokens: 177
# Cached tokens: 3584
# Non-cached tokens: 1231
# Output cost: 0.0007965
# Cached cost: 0.0002688
# Non-cached cost: 0.00092325

# %%
prompt_7 = f"""
Following is the text with more than 4000 tokens.
<text>
{text}
</text>
"""

# %%
response_7, raw_response_7 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractionResults,
    messages=[
        {"role": "system", "content": prompt_7},
        {"role": "user", "content": "Extract names from the text between <text> and </text> tags, leave places as null."},
    ]
)

# %%
response_8, raw_response_8 = client.chat.completions.create_with_completion(
    model="gpt-5.4-mini",
    response_model=ExtractionResults,
    messages=[
        {"role": "system", "content": prompt_7},
        {"role": "user", "content": "Extract names from the text between <text> and </text> tags, leave names as null."},
    ]
)

# %%
print_usage_and_cost(raw_response_7)
# Out:
# Input tokens: 4819
# Output tokens: 28
# Cached tokens: 3584
# Non-cached tokens: 1235
# Output cost: 0.000126
# Cached cost: 0.0002688
# Non-cached cost: 0.00092625

# %%
print_usage_and_cost(raw_response_8)
# Out:
# Input tokens: 4819
# Output tokens: 22
# Cached tokens: 4608
# Non-cached tokens: 211
# Output cost: 9.900000000000001e-05
# Cached cost: 0.0003456
# Non-cached cost: 0.00015825
